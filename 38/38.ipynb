# %%
import MeCab
import matplotlib
import pandas as pd
from pprint import pprint
import matplotlib.pyplot as plt

import sys
sys.path.append('/Users/ishiiasuka/Documents/GitHub/NLP100')
from package import read_text

# %%
df = read_text()
df = df[(df['pos1'] != '空白') & (df['surface'] != 'EOS') & (df['pos'] != '記号') & (df['surface'] != '記号')]
print(df.info())
print(df.head())
print(len(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 216300 entries, 0 to 226261
# Data columns (total 4 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   surface  216300 non-null  object
#  1   pos      216300 non-null  object
#  2   pos1     216300 non-null  object
#  3   base     206337 non-null  object
# dtypes: object(4)
# memory usage: 8.3+ MB
# None
#   surface     pos       pos1    base
# 0  ������  ������          *    None
# 2     ���  ������     ������     ���
# 3  ������  ������  ���������  ������
# 4     ���  ������  ���������     ���
# 5     ���  ������     ������     ���
# 216300

# %%
vc = df[df['pos'].str.startswith('助') == False]['surface']
vcv = vc.value_counts(ascending = False)
print(vcv)
# Out:
# ���                                                                119885
# ������                                                              78371
# ���������                                                           12069
# ������������                                                         4703
# ���������������                                                       760
# ������������������                                                    344
# ���������������������                                                  26
# ������������������������������������                                   22
# ���������������������������                                            21
# ������������������������                                               16
# ��                                                                     10
# ������������������������������                                          9
# 2                                                                       6
# Agnodice                                                                4
# cos                                                                     4
# T                                                                       4
# 1                                                                       3
# ���������������������������������������                                 3
# ���������������������������������                                       3
# the                                                                     3
# =                                                                       2
# a                                                                       2
# (                                                                       2
# )                                                                       2
# 3                                                                       2
# see                                                                     1
# slip                                                                    1
# boy                                                                     1
# Hierophilus                                                             1
# '                                                                       1
# Z                                                                       1
# cup                                                                     1
# A                                                                       1
# Savage                                                                  1
# Do                                                                      1
# many                                                                    1
# iomelesidonophrunicherata                                               1
# ���������������������������������������������������������������         1
# you                                                                     1
# .                                                                       1
# ������������������������������������������������                        1
# h                                                                       1
# c                                                                       1
# r                                                                       1
# lip                                                                     1
# Marcus                                                                  1
# twixt                                                                   1
# tea                                                                     1
# and                                                                     1
# Name: surface, dtype: int64

# %%
vc.nunique()
# Out:
# 49

# %%
vcv.hist()
# Out:
# <AxesSubplot:>
